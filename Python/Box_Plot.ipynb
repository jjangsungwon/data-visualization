# %% [markdown]
# ## 상자 그림(Box Plot)

# %%
# Import Library
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read csv file and assignment a dataframe
df = pd.read_csv('./data/iris_clabel.csv')

# %% [markdown]
# ### for whole columns

# %%
df.plot.box()
plt.show()
df.boxplot(column=['A','B','C','D'])
plt.show()

# %% [markdown]
# ### for Sepal-Length(A) only

# %%
df.boxplot(column=['A'], by='Label')
plt.show()

# %% [markdown]
# ### All features

# %%
df.boxplot(by='Label')
plt.show()
